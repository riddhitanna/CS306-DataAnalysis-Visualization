# %% [markdown]
# # Lab 9
# In this lab, we analyse the annual Stack Overflow Developer survey dataset from 2019.

# %% [markdown]
# **Riddhi Tanna**
#
# **201801427**

# %% [markdown]
# <hr>

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/Users/riddhi/Downloads/m1_survey_data.csv")
df
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %% [markdown]
# ## Finding duplicates

# %%
# maintaining a copy of the dataset
df_dup = df[df.duplicated()]
df_dup
# Out:
#       Respondent                                         MainBranch Hobbyist  \
# 1168        2339                     I am a developer by profession      Yes
# 1169        2342                     I am a developer by profession      Yes
# 1170        2343                     I am a developer by profession      Yes
# 1171        2344                     I am a developer by profession      Yes
# 1172        2347                     I am a developer by profession      Yes
# ...          ...                                                ...      ...
# 2297        4674  I am not primarily a developer, but I write co...      Yes
# 2298        4675                     I am a developer by profession      Yes
# 2299        4676                     I am a developer by profession      Yes
# 2300        4677                     I am a developer by profession      Yes
# 2301        4679                     I am a developer by profession      Yes
#
# ...

# %% [markdown]
# ## Removing duplicates

# %%
# finding duplicates
df_no_dup = df.drop_duplicates()

# %%
df_no_dup[df_no_dup.duplicated()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## Finding Missing values

# %%
df_no_dup[df_no_dup.notnull()]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 0               4  I am a developer by profession       No
# 1               9  I am a developer by profession      Yes
# 2              13  I am a developer by profession      Yes
# 3              16  I am a developer by profession      Yes
# 4              17  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 11547       25136  I am a developer by profession      Yes
# 11548       25137  I am a developer by profession      Yes
# 11549       25138  I am a developer by profession      Yes
# 11550       25141  I am a developer by profession      Yes
# 11551       25142  I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# 0                                                  Never
# 1                             Once a month or more often
# 2      Less than once a month but more than once per ...
# ...

# %%
df_no_dup[df_no_dup['WorkLoc'].isnull()]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 130           285                     I am a developer by profession      Yes
# 242           550                     I am a developer by profession      Yes
# 866          1847                     I am a developer by profession      Yes
# 1455         2826                     I am a developer by profession      Yes
# 1753         3536                     I am a developer by profession      Yes
# 2339         4768                     I am a developer by profession      Yes
# 2689         5562                     I am a developer by profession       No
# 2788         5769                     I am a developer by profession      Yes
# 3165         6613                     I am a developer by profession       No
# 3213         6721                     I am a developer by profession       No
# 3690         7799  I am not primarily a developer, but I write co...      Yes
# ...

# %% [markdown]
# As we can see above, we have 32 rows where the work location is missing. We either need to drop them or impute the values. We can impute these values so that there is no bias in our analysis.

# %% [markdown]
# ## Imputing missing values

# %%
df['WorkLoc'].value_counts()
# Out:
# Office                                            6905
# Home                                              3638
# Other place, such as a coworking space or cafe     977
# Name: WorkLoc, dtype: int64

# %% [markdown]
# Most people work in their offices

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the 'Office' since that is the most likely work location.

# %%
df['WorkLoc'].fillna('Office', inplace=True)
df[df['WorkLoc'].isnull()]
# Out:
# Empty DataFrame
# ...

# %% [markdown]
# ## Normalizing data

# %%
# your code goes here
df['CompFreq'].value_counts()
# Out:
# Yearly     6163
# Monthly    4846
# Weekly      337
# Name: CompFreq, dtype: int64

# %%
for i in range(0,len(df)):
    freq=df['CompFreq'][i]
    if (freq=='Monthly'):
        df['NormalizedAnnualCompensation']=df['CompTotal']*12
    elif (freq=='Weekly'):
        df['NormalizedAnnualCompensation']=df['CompTotal']*52
    else:
        df['NormalizedAnnualCompensation']=df['CompTotal']
df['NormalizedAnnualCompensation']
# Out:
# 0         61000.0
# 1        138000.0
# 2         90000.0
# 3         29000.0
# 4         90000.0
#            ...
# 11547    130000.0
# 11548     74400.0
# 11549    105000.0
# 11550     80000.0
# 11551         NaN
# Name: NormalizedAnnualCompensation, Length: 11552, dtype: float64

# %% [markdown]
# # Visualizations

# %% [markdown]
# ## Histogram of the normalized compensation

# %%
import seaborn as sns
sns.set(rc={'figure.figsize':(11.7,8.27)})
sns.histplot(df['ConvertedComp'])
# Out:
# <AxesSubplot:xlabel='ConvertedComp', ylabel='Count'>

# %% [markdown]
# A histogram of the compensation provided to developers can give us an idea about how the compensations are skewed, or if they are skewed at all. It shows us the distribution of the compensation. Here, we can see that the compensation is right skewed.

# %% [markdown]
# ## Heatmap representing the correlations between different variables of the dataset

# %%
#Finding the correlation
sns.heatmap(a)
a = df.corr()
# Out:
# <AxesSubplot:>

# %% [markdown]
# A heatmap is a great tool to visualize the correlation between sets of variables. In the above case, we can see that most variables have almost 0 correlation.

# %% [markdown]
# ## Scatter plot of the age vs work week hours

# %%
sns.scatterplot(x=df['Age'],y=df['WorkWeekHrs'], s=100, edgecolor='none', color='r')
plt.title('Scatter plot of Work Week Hours vs Age', fontsize=16)
plt.show()

# %% [markdown]
# We can use scatter plots to observe relationships between two variables. In this case, we can see that most people, no matter what age the are, have similar work week hours, with a few outliers.

# %% [markdown]
# ## Pie Chart

# %%
import matplotlib.pyplot as plt
values = df['DatabaseDesireNextYear'].value_counts()
labels = df['DatabaseDesireNextYear'].unique()
plt.title('Top 5 databases desired by respondents next year', fontsize=16, color='k')
plt.pie(values[0:5],labels=labels[0:5],shadow=True,explode=(0.05,0.05,0.05,0.05,0.05))  
plt.show()
#Pie chart for the top 5 
#databases that respondents wish to learn next year

# %% [markdown]
# A pie chart is a good way to represent the composition of a categorical variable such as the one we have above.

# %% [markdown]
# ## Horizontal bar graph

# %%
unique = df['MainBranch'].unique()
values = df['MainBranch'].value_counts()
print(values)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
#Bar chart representing the count in the different branches 
plt.barh(unique,values)  
plt.show()
# Out:
# I am a developer by profession                                                   10758
# I am not primarily a developer, but I write code sometimes as part of my work      794
# Name: MainBranch, dtype: int64

# %% [markdown]
# A horizontal bar graph can be used to compare the values of a particular variable when the labels are too long to be displayed on the x-axis. Here, we can clearly see that most respondents are developers by profession and some of them sometimes write code as part of their work.
